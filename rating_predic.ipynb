# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import Counter
import pandas as pd
import csv
import torch
from transformers import AutoTokenizer, AutoModel

# %% [markdown]
# ## Import Data

# %%
movies_df = pd.read_csv("./ml-latest-small/movies.csv")
tags_df = pd.read_csv("./ml-latest-small/tags.csv")

# %%
user_dat = open("./ml-1m/users.dat")

# %%
columns_to_keep = ['userId', 'gender', "age", "occupation"]

user_dat = open("./ml-1m/users.dat")
datContent=[]
for idx,val in enumerate(user_dat.readlines()):
    if idx==0:
        datContent.append(['userId', 'gender', "age", "occupation"])
    datContent.append(val.strip().split("::"))

with open("./users.csv", "w") as f:
    writer = csv.writer(f)
    writer.writerows(datContent)

columns_to_keep = ['userId', 'gender', "age", "occupation"]

user_df = pd.read_csv("./users.csv", usecols=columns_to_keep).set_index("userId")
user_df
# Out:
#        gender  age  occupation
# userId
# 1           F    1          10
# 2           M   56          16
# 3           M   25          15
# 4           M   45           7
# 5           M   25          20
# ...       ...  ...         ...
# 6036        F   25          15
# 6037        F   45           1
# 6038        F   56           1
# 6039        F   45           0
# 6040        M   25           6
#
# [6040 rows x 3 columns]

# %%
ratings_dat = open("./ml-1m/ratings.dat")

datContent=[]
for idx,val in enumerate(ratings_dat.readlines()):
    if idx==0:
        datContent.append(['userId', 'movieId', "rating"])
    datContent.append(val.strip().split("::") )

with open("./ratings.csv", "w") as f:
    writer = csv.writer(f)
    writer.writerows(datContent)


columns_to_keep = ['userId', 'movieId', "rating"]
ratings_df = pd.read_csv("./ratings.csv", usecols=columns_to_keep)
ratings_df
# Out:
#          userId  movieId  rating
# 0             1     1193       5
# 1             1      661       3
# 2             1      914       3
# 3             1     3408       4
# 4             1     2355       5
# ...         ...      ...     ...
# 1000204    6040     1091       1
# 1000205    6040     1094       5
# 1000206    6040      562       5
# 1000207    6040     1096       4
# 1000208    6040     1097       4
#
# [1000209 rows x 3 columns]

# %%
user_id = 1

# %% [markdown]
# ## Get users gender, age, and occupation

# %%
user = user_df[user_df.index==user_id][["gender","age","occupation"]]
u_gender = user["gender"].to_list()[0]
u_age = user["age"].to_list()[0]
u_occ = user["occupation"].to_list()[0]

# %% [markdown]
# ## Get other users with the same gender and age range and users occupation

# %%
same_gen_age_range = (user_df["gender"]==u_gender)&(user_df["age"]<u_age+5)&(user_df["age"]>u_age-5)
same_occ = (user_df["occupation"]==u_occ)
friends = user_df[same_gen_age_range | same_occ]
# The following line determines how many friends we use to predict rating
friends = friends.iloc[:1]
friends
# Out:
#        gender  age  occupation
# userId
# 1           F    1          10

# %% [markdown]
# ## Get the user and their friends previously rated movies

# %%
user_data = pd.merge(friends, ratings_df, how="inner", on='userId')

# %% [markdown]
# ## Group the tags for each movieId to bucket_of_tags

# %%
bucket_of_tags = tags_df[["movieId","tag"]]
bucket_of_tags = bucket_of_tags.groupby('movieId',as_index=False).agg(lambda x: ' '.join(map(str,x)))

movie_tags = pd.merge(bucket_of_tags, movies_df, how="outer", on='movieId')

del movie_tags["genres"]
bucket_of_tags = movie_tags

bucket_of_tags
# Out:
#       movieId                                           tag  \
# 0           1                               pixar pixar fun
# 1           2  fantasy magic board game Robin Williams game
# 2           3                                     moldy old
# 3           5                              pregnancy remake
# 4           7                                        remake
# ...       ...                                           ...
# 9737   193581                                           NaN
# 9738   193583                                           NaN
# 9739   193585                                           NaN
# 9740   193587                                           NaN
# 9741   193609                                           NaN
#
#                                           title
# 0                              Toy Story (1995)
# 1                                Jumanji (1995)
# 2                       Grumpier Old Men (1995)
# 3            Father of the Bride Part II (1995)
# 4                                Sabrina (1995)
# ...                                         ...
# 9737  Black Butler: Book of the Atlantic (2017)
# 9738               No Game No Life: Zero (2017)
# 9739                               Flint (2017)
# 9740        Bungo Stray Dogs: Dead Apple (2018)
# 9741        Andrew Dice Clay: Dice Rules (1991)
#
# [9742 rows x 3 columns]

# %% [markdown]
# ## Add the tags to the user (and their firends) previously rated movies

# %%
user_rated_tags = pd.merge(user_data, bucket_of_tags, how="outer", on='movieId')[["movieId","rating","tag","title"]]
user_rated_tags = user_rated_tags.dropna(how='any',subset=['rating',"tag"])

user_rated_tags.shape
# Out:
# (40, 4)

# %%
movie_id = 914
candidate = bucket_of_tags[bucket_of_tags["movieId"]==movie_id]
_data = [candidate["movieId"].to_string(index=False), 0, candidate["tag"
].to_string(index=False),candidate["title"].to_string(index=False)]
_val = pd.DataFrame([_data], columns= ["movieId","rating", "tag","title"
])


if movie_id in user_rated_tags["movieId"].to_list():
    user_rated_tags = user_rated_tags.reset_index()
    index  = user_rated_tags[user_rated_tags["movieId"]==movie_id].index.to_list()[0]
    indices = user_rated_tags.index.to_list()
    indices[index], indices[-1] = indices[-1], indices[index]
    user_rated_tags = user_rated_tags.reindex(indices)
else:
    user_rated_tags.loc[-1] =_data

user_rated_tags
# Out:
#     index  movieId  rating                                                tag  \
# 0       0     1193     5.0            emotional jack nicholson mental illness
# 39     52     1246     4.0                             highschool High School
# 2       3     3408     4.0                                 scandal true story
# 3       4     2355     5.0                                              Pixar
# 4       5     1197     3.0                     Inigo Montoya six-fingered man
# 5       7     2804     5.0                                          Christmas
# 6       8      594     4.0                                             Disney
# 7       9      919     4.0                                       Dorothy Toto
# 8      10      595     5.0                                             Disney
# 9      11      938     4.0                                       prostitution
# 10     13     2918     4.0                                        High School
# 11     14     1035     5.0                             Rogers and Hammerstein
# 12     15     2791     4.0                                     aviation spoof
# 13     19     2797     4.0                                           children
# 14     21      720     3.0                                            Aardman
# 15     22     1270     5.0                                        time travel
# 16     23      527     5.0  moving thought-provoking Holocaust based on a ...
# 17     26     1097     4.0                                             aliens
# 18     27     1721     4.0                                  shipwreck romance
# 19     28     1545     4.0                                              death
# 20     29      745     3.0                                            Aardman
# 21     31     3186     4.0  asylum based on a true story Brittany Murphy M...
# 22     33      588     4.0                                             Disney
# 23     36     1836     5.0                                  No DVD at Netflix
# 24     37     1022     5.0                                             Disney
# 25     38     2762     4.0  Atmospheric Bruce Willis ghosts imdb top 250 m...
# 26     39      150     5.0                                    moon NASA space
# 27     40        1     5.0                                    pixar pixar fun
# 28     41     1961     5.0                                             autism
# 29     42     1962     4.0                                             rasicm
# 30     43     2692     4.0                                  alternate endings
# 31     44      260     4.0  classic space action action sci-fi EPIC great ...
# 32     45     1028     5.0                                       Disney nanny
# 33     46     1029     5.0                                             Disney
# 34     47     1207     4.0                                  Harper Lee racism
# 35     48     2028     5.0                                       World War II
# 36     49      531     4.0                                   In Netflix queue
# 37     50     3114     4.0  animation Disney funny original Pixar sequel T...
# 38     51      608     4.0  based on a true story dark comedy KIDNAPPING S...
# 1       2      914     3.0                                George Bernard Shaw
#
#                                                 title
# 0              One Flew Over the Cuckoo's Nest (1975)
# 39                          Dead Poets Society (1989)
# 2                              Erin Brockovich (2000)
# 3                                Bug's Life, A (1998)
# 4                          Princess Bride, The (1987)
# 5                           Christmas Story, A (1983)
# 6              Snow White and the Seven Dwarfs (1937)
# 7                            Wizard of Oz, The (1939)
# 8                         Beauty and the Beast (1991)
# 9                                         Gigi (1958)
# 10                    Ferris Bueller's Day Off (1986)
# 11                         Sound of Music, The (1965)
# 12                                   Airplane! (1980)
# 13                                         Big (1988)
# 14  Wallace & Gromit: The Best of Aardman Animatio...
# 15                          Back to the Future (1985)
# 16                            Schindler's List (1993)
# 17                  E.T. the Extra-Terrestrial (1982)
# 18                                     Titanic (1997)
# 19                                     Ponette (1996)
# 20             Wallace & Gromit: A Close Shave (1995)
# 21                           Girl, Interrupted (1999)
# 22                                     Aladdin (1992)
# 23                     Last Days of Disco, The (1998)
# 24                                  Cinderella (1950)
# 25                            Sixth Sense, The (1999)
# 26                                   Apollo 13 (1995)
# 27                                   Toy Story (1995)
# 28                                    Rain Man (1988)
# 29                          Driving Miss Daisy (1989)
# 30                   Run Lola Run (Lola rennt) (1998)
# 31          Star Wars: Episode IV - A New Hope (1977)
# 32                                Mary Poppins (1964)
# 33                                       Dumbo (1941)
# 34                       To Kill a Mockingbird (1962)
# 35                         Saving Private Ryan (1998)
# 36                          Secret Garden, The (1993)
# 37                                 Toy Story 2 (1999)
# 38                                       Fargo (1996)
# 1                                 My Fair Lady (1964)

# %% [markdown]
# ## Import bert model

# %%
model_name = "sentence-transformers/bert-base-nli-mean-tokens"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)

# %%
tokens = {"input_ids": [], "attention_mask": []}

# %% [markdown]
# ## Populate tokens with the embedded tags

# %%
for tag in user_rated_tags["tag"].to_list():
    new_tokens = tokenizer.encode_plus(tag, max_length=128, truncation=True, padding="max_length",return_tensors='pt')

    tokens['input_ids'].append(new_tokens['input_ids'][0])
    tokens['attention_mask'].append(new_tokens['attention_mask'][0])

tokens['input_ids'] = torch.stack(tokens['input_ids'])
tokens['attention_mask'] = torch.stack(tokens['attention_mask'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/kk/kbgqpj057pl2zf56qtvlqbm00000gn/T/ipykernel_61346/2619644408.py in <module>
#       2     new_tokens = tokenizer.encode_plus(tag, max_length=128, truncation=True, padding="max_length",return_tensors='pt')
#       3
# ----> 4     tokens['input_ids'].append(new_tokens['input_ids'][0])
#       5     tokens['attention_mask'].append(new_tokens['attention_mask'][0])
#       6
#
# AttributeError: 'Tensor' object has no attribute 'append'

# %% [markdown]
# ## Run the model

# %%
output = model(**tokens)

# %% [markdown]
# ## Get latest embeddings

# %%
embedding = output.last_hidden_state
attention = tokens["attention_mask"]
mask = attention.unsqueeze(-1).expand(embedding.shape).float()
mask_embeddings = embedding * mask

# %%
summed = torch.sum(mask_embeddings, 1)

# %%
counts = torch.clamp(mask.sum(1), min=1e-9)

# %%
mean_pooled = summed / counts
mean_pooled
# Out:
# tensor([[-0.0889, -0.0111,  0.6810,  ..., -0.9847, -0.4998, -0.8268],
#         [-0.6878,  0.5000,  0.7699,  ..., -0.1668,  0.1444, -0.3699],
#         [-0.1046, -0.3171,  1.0704,  ...,  0.1529,  0.0250,  0.0140],
#         ...,
#         [-0.2367,  0.7916,  0.8158,  ..., -0.2780,  0.7770,  0.3085],
#         [-0.2544,  0.4656,  0.4933,  ..., -0.3380,  0.3432,  0.1238],
#         [ 0.4517,  0.6184,  0.9609,  ..., -0.4463,  0.0583,  1.0208]],
#        grad_fn=<DivBackward0>)

# %% [markdown]
# ## Calculate cosine_similarity

# %%
mean_pooled = mean_pooled.detach().numpy()
sim = cosine_similarity([mean_pooled[-1]],mean_pooled)

# %%
sim
# Out:
# array([[0.44363657, 0.36449295, 0.39045584, 0.49386793, 0.45102543,
#         0.47906128, 0.42879874, 0.57736313, 0.42879874, 0.24651174,
#         0.4420464 , 0.65056694, 0.3344221 , 0.33420146, 0.63834953,
#         0.39429706, 0.3369038 , 0.28744066, 0.42245883, 0.4744112 ,
#         0.63834953, 0.2914983 , 0.42879874, 0.09540707, 0.42879874,
#         0.23277798, 0.12350664, 0.35783312, 0.3340716 , 0.658965  ,
#         0.47443762, 0.12841475, 0.31717908, 0.42879874, 0.47248077,
#         0.522052  , 0.30776656, 0.28666508, 0.25673655, 1.0000001 ]],
#       dtype=float32)

# %%
user_rated_tags["cosine_similarity"] = sim[0]
user_rated_tags
# Out:
#     index  movieId  rating                                                tag  \
# 0       0     1193     5.0            emotional jack nicholson mental illness
# 39     52     1246     4.0                             highschool High School
# 2       3     3408     4.0                                 scandal true story
# 3       4     2355     5.0                                              Pixar
# 4       5     1197     3.0                     Inigo Montoya six-fingered man
# 5       7     2804     5.0                                          Christmas
# 6       8      594     4.0                                             Disney
# 7       9      919     4.0                                       Dorothy Toto
# 8      10      595     5.0                                             Disney
# 9      11      938     4.0                                       prostitution
# 10     13     2918     4.0                                        High School
# 11     14     1035     5.0                             Rogers and Hammerstein
# 12     15     2791     4.0                                     aviation spoof
# 13     19     2797     4.0                                           children
# 14     21      720     3.0                                            Aardman
# 15     22     1270     5.0                                        time travel
# 16     23      527     5.0  moving thought-provoking Holocaust based on a ...
# 17     26     1097     4.0                                             aliens
# 18     27     1721     4.0                                  shipwreck romance
# 19     28     1545     4.0                                              death
# 20     29      745     3.0                                            Aardman
# 21     31     3186     4.0  asylum based on a true story Brittany Murphy M...
# 22     33      588     4.0                                             Disney
# 23     36     1836     5.0                                  No DVD at Netflix
# 24     37     1022     5.0                                             Disney
# 25     38     2762     4.0  Atmospheric Bruce Willis ghosts imdb top 250 m...
# 26     39      150     5.0                                    moon NASA space
# 27     40        1     5.0                                    pixar pixar fun
# 28     41     1961     5.0                                             autism
# 29     42     1962     4.0                                             rasicm
# 30     43     2692     4.0                                  alternate endings
# 31     44      260     4.0  classic space action action sci-fi EPIC great ...
# 32     45     1028     5.0                                       Disney nanny
# 33     46     1029     5.0                                             Disney
# 34     47     1207     4.0                                  Harper Lee racism
# 35     48     2028     5.0                                       World War II
# 36     49      531     4.0                                   In Netflix queue
# 37     50     3114     4.0  animation Disney funny original Pixar sequel T...
# 38     51      608     4.0  based on a true story dark comedy KIDNAPPING S...
# 1       2      914     3.0                                George Bernard Shaw
#
#                                                 title  cosine_similarity
# 0              One Flew Over the Cuckoo's Nest (1975)           0.443637
# 39                          Dead Poets Society (1989)           0.364493
# 2                              Erin Brockovich (2000)           0.390456
# 3                                Bug's Life, A (1998)           0.493868
# 4                          Princess Bride, The (1987)           0.451025
# 5                           Christmas Story, A (1983)           0.479061
# 6              Snow White and the Seven Dwarfs (1937)           0.428799
# 7                            Wizard of Oz, The (1939)           0.577363
# 8                         Beauty and the Beast (1991)           0.428799
# 9                                         Gigi (1958)           0.246512
# 10                    Ferris Bueller's Day Off (1986)           0.442046
# 11                         Sound of Music, The (1965)           0.650567
# 12                                   Airplane! (1980)           0.334422
# 13                                         Big (1988)           0.334201
# 14  Wallace & Gromit: The Best of Aardman Animatio...           0.638350
# 15                          Back to the Future (1985)           0.394297
# 16                            Schindler's List (1993)           0.336904
# 17                  E.T. the Extra-Terrestrial (1982)           0.287441
# 18                                     Titanic (1997)           0.422459
# 19                                     Ponette (1996)           0.474411
# 20             Wallace & Gromit: A Close Shave (1995)           0.638350
# 21                           Girl, Interrupted (1999)           0.291498
# 22                                     Aladdin (1992)           0.428799
# 23                     Last Days of Disco, The (1998)           0.095407
# 24                                  Cinderella (1950)           0.428799
# 25                            Sixth Sense, The (1999)           0.232778
# 26                                   Apollo 13 (1995)           0.123507
# 27                                   Toy Story (1995)           0.357833
# 28                                    Rain Man (1988)           0.334072
# 29                          Driving Miss Daisy (1989)           0.658965
# 30                   Run Lola Run (Lola rennt) (1998)           0.474438
# 31          Star Wars: Episode IV - A New Hope (1977)           0.128415
# 32                                Mary Poppins (1964)           0.317179
# 33                                       Dumbo (1941)           0.428799
# 34                       To Kill a Mockingbird (1962)           0.472481
# 35                         Saving Private Ryan (1998)           0.522052
# 36                          Secret Garden, The (1993)           0.307767
# 37                                 Toy Story 2 (1999)           0.286665
# 38                                       Fargo (1996)           0.256737
# 1                                 My Fair Lady (1964)           1.000000

# %% [markdown]
# ## Get Weighted Mean

# %%
weighted_mean = sum(user_rated_tags["cosine_similarity"] * user_rated_tags["rating"])/(sum(user_rated_tags["cosine_similarity"]))

# %%
weighted_mean
# Out:
# 4.189412417861589
